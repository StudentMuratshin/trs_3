# %%
import numpy as np
import matplotlib.pyplot as plt

# задаем значения x и y
x = np.linspace(0, 2, 100)
y = np.linspace(0, 1, 100)

# задаем функцию, которую будем рисовать
def u(x,y):
    return np.sin(np.pi*x/2)*np.sin(np.pi*y)*np.sin(np.pi*y)



# добавляем подписи осей и заголовок
ax.set_xlabel('x')
ax.set_ylabel('z')
ax.set_title('График функции $\sin(\pi x/2)\sin(\pi y)\sin(\pi y)$ при y=0')

# отображаем график
plt.show()
